# %% [markdown]
# # Importing necassary libraries

# %%
import numpy as np
import scipy.io
from python_speech_features import mfcc
import matplotlib.pyplot as plt
import IPython.display as ipd
import os
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import soundfile as sf
import random
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
import joblib
import math
import statistics

# %% [markdown]
# # Defining the function that reads the audios from a given path using soundfile and returns 4 lists : audios, freqs, filepaths and problematic files for potential debugging

# %%
def read_audios(directory):
    audios = []
    freqs = []
    filepaths = []
    problematic_files = []
    
    # Walking through the directory that contains the dataset and reading each file that has the .wav extension
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.wav'):
                filepath = os.path.join(root, file)
                filepaths.append(filepath)
                try:
                    # Read the audio file using soundfile
                    data, freq = sf.read(filepath)
                    audios.append(data)
                    freqs.append(freq)
                except Exception as e:
                    print(f"Encountered an error with file: {filepath}. Error: {e}")
                    problematic_files.append(filepath)
    
    return audios, freqs, filepaths, problematic_files

# Example usage
audios, freqs, filepaths, problematic_files = read_audios(r'Spanish_wav')

# %% [markdown]
# # Defining the function that extracts the mfcc features then removes the frames of silence finally it saves the mffc features into a .txt file according to gender

# %%
def extractMfccs_RemoveSilence_saveMfccs(audios,freqs,filepaths, directory):
    mfccs = []
 
    for audio, freq, filepath in zip(audios, freqs,filepaths):
        # extract the MFCC features
        mfcc_features = mfcc(audio, freq, winlen=0.025, winstep=0.01, numcep=13, nfilt=26, nfft= 2048, lowfreq=0,
                         highfreq=None, preemph=0.97, ceplifter=22, appendEnergy=False)
        
        # calculate the energy
        energy = np.sum(mfcc_features**2, axis=1)
        # calculate the threshold for silence
        threshold = np.mean(energy) * 0.4
        #removing silence frames from mfccs
        voiced_indices = np.where(energy > threshold)[0]
        mfccs_voiced = mfcc_features[voiced_indices,:]
        mfccs.append(mfccs_voiced)
        
        # print the shape of the MFCCs before and after removing silence
        print(f"MFCCs before removing silence: {mfcc_features.shape}")
        print(f"MFCCs after removing silence: {mfccs_voiced.shape}")
        
       #saving mffcs 
       # extract the gender information from the file name
        gender = None
        if 'hommes' in filepath:
            gender = 'Hommes'
        elif 'femmes' in filepath:
            gender = 'Femmes'

        # save the MFCCs to the appropriate directory based on gender
        if gender is not None:
            gender_dir = os.path.join(directory, gender)
            if not os.path.exists(gender_dir):
                os.makedirs(gender_dir)
            mfcc_file = os.path.join(gender_dir,  os.path.splitext(os.path.basename(filepath))[0] + ".mfcc")
            np.savetxt(mfcc_file, mfccs_voiced, delimiter=',')
            
      
    
    return  mfccs

# %% [markdown]
# # Defining the function that splits the extraced mfccs into training and testing sets : 2/3 from male directory for training and 2/3 from female

# %%
def train_test_split(mfcc_dir):
    # create separate lists for male and female file paths
    male_files = []
    female_files = []
    for root, dirs, files in os.walk(mfcc_dir):
        for file in files:
            if file.endswith('.mfcc'):
                if 'Hommes' in root:
                    male_files.append(os.path.join(root, file))
                elif 'Femmes' in root:
                    female_files.append(os.path.join(root, file))

    # shuffle the male and female lists independently
    random.shuffle(male_files)
    random.shuffle(female_files)

    # split the male and female lists into train and test based on the desired ratio
    male_train = male_files[:int(2/3*len(male_files))]
    male_test = male_files[int(2/3*len(male_files)):]

    female_train = female_files[:int(2/3*len(female_files))]
    female_test = female_files[int(2/3*len(female_files)):]

    
    
    # merge the train and test lists for both male and female
    train_files = male_train + female_train
    test_files = male_test + female_test

    # load the MFCC features from the saved files for the train and test sets
    train_mfccs = []
    test_mfccs = []

    for file in train_files:
        train_mfccs.append(np.loadtxt(file, delimiter=','))

    for file in test_files:
        test_mfccs.append(np.loadtxt(file, delimiter=','))

    # print the shapes of the train and test MFCC feature arrays
    print(f"Train male MFCCs shape: {np.array(male_train).shape}")
    print(f"Test male MFCCs shape: {np.array( male_test).shape}")
    print(f"Train female MFCCs shape: {np.array(female_train).shape}")
    print(f"Test female MFCCs shape: {np.array( female_test).shape}")
    print(f"Train MFCCs shape: {np.array(train_mfccs).shape}")
    print(f"Test MFCCs shape: {np.array(test_mfccs).shape}")
    
    return train_mfccs, test_mfccs

# %% [markdown]
# # Defining the functions that train the different GMM models and than save them as a pkl file

# %%
def gmm16(train_mfccs):
    # Initialize the GMM model with 16 classes
    gmm = GaussianMixture(n_components=16, covariance_type='diag', random_state=0)

    # Fit the GMM model to the training data
    gmm.fit(train_mfccs)
    
    # Save the trained GMM model to a file
    joblib.dump(gmm, r'gmm_model16_spanish.pkl')

    return gmm

# %%
def gmm32(train_mfccs):
    # Initialize the GMM model with 32 classes
    gmm = GaussianMixture(n_components=32, covariance_type='diag', random_state=0)

    # Fit the GMM model to the training data
    gmm.fit(train_mfccs)
    
    # Save the trained GMM model to a file
    joblib.dump(gmm, r'gmm_model32_spanish.pkl')

    return gmm

# %%
def gmm64(train_mfccs):
    # Initialize the GMM model with 64 classes
    gmm = GaussianMixture(n_components=64, covariance_type='diag', random_state=0)

    # Fit the GMM model to the training data
    gmm.fit(train_mfccs)
    
    # Save the trained GMM model to a file
    joblib.dump(gmm, r'gmm_model64_spanish.pkl')

    return gmm

# %%
def gmm128(train_mfccs):
    # Initialize the GMM model with 128 classes
    gmm = GaussianMixture(n_components=128, covariance_type='diag', random_state=0)

    # Fit the GMM model to the training data
    gmm.fit(train_mfccs)
    
    # Save the trained GMM model to a file
    joblib.dump(gmm, r'gmm_model128_spanish.pkl')

    return gmm

# %%
def gmm256(train_mfccs):
    # Initialize the GMM model with 254 classes
    gmm = GaussianMixture(n_components=256, covariance_type='diag', random_state=0)

    # Fit the GMM model to the training data
    gmm.fit(train_mfccs)
    
    # Save the trained GMM model to a file
    joblib.dump(gmm, r'gmm_model256_spanish.pkl')

    return gmm

# %% [markdown]
# # Getting the audios frequencies and filepaths from their directory using the function defined above

# %%
audios, freqs, filepaths, problematic_files = read_audios(r'Spanish_wav')

# %% [markdown]
# # Extracting the mfcc features - Removing silence and saving the mfccs

# %%
mfccs = extractMfccs_RemoveSilence_saveMfccs(audios, freqs, filepaths,r'mfcc_spanish')
# Out:
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (534, 13)
# MFCCs after removing silence: (534, 13)
# MFCCs before removing silence: (482, 13)
# MFCCs after removing silence: (482, 13)
# MFCCs before removing silence: (482, 13)
# MFCCs after removing silence: (482, 13)
# MFCCs before removing silence: (519, 13)
# MFCCs after removing silence: (519, 13)
# MFCCs before removing silence: (527, 13)
# MFCCs after removing silence: (527, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (533, 13)
# MFCCs after removing silence: (533, 13)
# MFCCs before removing silence: (468, 13)
# MFCCs after removing silence: (468, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (527, 13)
# MFCCs after removing silence: (527, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (475, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (519, 13)
# MFCCs after removing silence: (519, 13)
# MFCCs before removing silence: (476, 13)
# MFCCs after removing silence: (476, 13)
# MFCCs before removing silence: (563, 13)
# MFCCs after removing silence: (563, 13)
# MFCCs before removing silence: (520, 13)
# MFCCs after removing silence: (519, 13)
# MFCCs before removing silence: (468, 13)
# MFCCs after removing silence: (468, 13)
# MFCCs before removing silence: (541, 13)
# MFCCs after removing silence: (541, 13)
# MFCCs before removing silence: (482, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (505, 13)
# MFCCs after removing silence: (505, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (519, 13)
# MFCCs after removing silence: (519, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (520, 13)
# MFCCs after removing silence: (520, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (541, 13)
# MFCCs after removing silence: (541, 13)
# MFCCs before removing silence: (520, 13)
# MFCCs after removing silence: (520, 13)
# MFCCs before removing silence: (468, 13)
# MFCCs after removing silence: (468, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (453, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (482, 13)
# MFCCs after removing silence: (482, 13)
# MFCCs before removing silence: (513, 13)
# MFCCs after removing silence: (513, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (496, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (520, 13)
# MFCCs after removing silence: (520, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (548, 13)
# MFCCs after removing silence: (548, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (483, 13)
# MFCCs after removing silence: (483, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (475, 13)
# MFCCs before removing silence: (292, 13)
# MFCCs after removing silence: (292, 13)
# MFCCs before removing silence: (585, 13)
# MFCCs after removing silence: (585, 13)
# MFCCs before removing silence: (541, 13)
# MFCCs after removing silence: (541, 13)
# MFCCs before removing silence: (476, 13)
# MFCCs after removing silence: (476, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (462, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (549, 13)
# MFCCs after removing silence: (549, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (519, 13)
# MFCCs after removing silence: (519, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (475, 13)
# MFCCs before removing silence: (468, 13)
# MFCCs after removing silence: (468, 13)
# MFCCs before removing silence: (527, 13)
# MFCCs after removing silence: (527, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (508, 13)
# MFCCs after removing silence: (508, 13)
# MFCCs before removing silence: (610, 13)
# MFCCs after removing silence: (610, 13)
# MFCCs before removing silence: (602, 13)
# MFCCs after removing silence: (602, 13)
# MFCCs before removing silence: (14, 13)
# MFCCs after removing silence: (14, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (496, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (508, 13)
# MFCCs after removing silence: (508, 13)
# MFCCs before removing silence: (520, 13)
# MFCCs after removing silence: (520, 13)
# MFCCs before removing silence: (473, 13)
# MFCCs after removing silence: (473, 13)
# MFCCs before removing silence: (484, 13)
# MFCCs after removing silence: (484, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (496, 13)
# MFCCs before removing silence: (485, 13)
# MFCCs after removing silence: (485, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (550, 13)
# MFCCs before removing silence: (478, 13)
# MFCCs after removing silence: (478, 13)
# MFCCs before removing silence: (515, 13)
# MFCCs after removing silence: (515, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (484, 13)
# MFCCs after removing silence: (484, 13)
# MFCCs before removing silence: (508, 13)
# MFCCs after removing silence: (508, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (508, 13)
# MFCCs after removing silence: (508, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (443, 13)
# MFCCs after removing silence: (443, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (484, 13)
# MFCCs after removing silence: (484, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (531, 13)
# MFCCs after removing silence: (531, 13)
# MFCCs before removing silence: (497, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (449, 13)
# MFCCs after removing silence: (449, 13)
# MFCCs before removing silence: (472, 13)
# MFCCs after removing silence: (472, 13)
# MFCCs before removing silence: (526, 13)
# MFCCs after removing silence: (526, 13)
# MFCCs before removing silence: (479, 13)
# MFCCs after removing silence: (479, 13)
# MFCCs before removing silence: (531, 13)
# MFCCs after removing silence: (531, 13)
# MFCCs before removing silence: (473, 13)
# MFCCs after removing silence: (473, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (496, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (508, 13)
# MFCCs after removing silence: (508, 13)
# MFCCs before removing silence: (574, 13)
# MFCCs after removing silence: (574, 13)
# MFCCs before removing silence: (455, 13)
# MFCCs after removing silence: (455, 13)
# MFCCs before removing silence: (431, 13)
# MFCCs after removing silence: (431, 13)
# MFCCs before removing silence: (803, 13)
# MFCCs after removing silence: (803, 13)
# MFCCs before removing silence: (753, 13)
# MFCCs after removing silence: (753, 13)
# MFCCs before removing silence: (375, 13)
# MFCCs after removing silence: (375, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (452, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (474, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (497, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (484, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (480, 13)
# MFCCs after removing silence: (479, 13)
# MFCCs before removing silence: (476, 13)
# MFCCs after removing silence: (473, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (486, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (453, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (470, 13)
# MFCCs after removing silence: (469, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (470, 13)
# MFCCs after removing silence: (469, 13)
# MFCCs before removing silence: (27, 13)
# MFCCs after removing silence: (27, 13)
# MFCCs before removing silence: (465, 13)
# MFCCs after removing silence: (465, 13)
# MFCCs before removing silence: (470, 13)
# MFCCs after removing silence: (470, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (499, 13)
# MFCCs before removing silence: (436, 13)
# MFCCs after removing silence: (436, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (464, 13)
# MFCCs after removing silence: (464, 13)
# MFCCs before removing silence: (526, 13)
# MFCCs after removing silence: (522, 13)
# MFCCs before removing silence: (509, 13)
# MFCCs after removing silence: (508, 13)
# MFCCs before removing silence: (464, 13)
# MFCCs after removing silence: (464, 13)
# MFCCs before removing silence: (516, 13)
# MFCCs after removing silence: (516, 13)
# MFCCs before removing silence: (435, 13)
# MFCCs after removing silence: (435, 13)
# MFCCs before removing silence: (397, 13)
# MFCCs after removing silence: (397, 13)
# MFCCs before removing silence: (444, 13)
# MFCCs after removing silence: (444, 13)
# MFCCs before removing silence: (488, 13)
# MFCCs after removing silence: (485, 13)
# MFCCs before removing silence: (425, 13)
# MFCCs after removing silence: (424, 13)
# MFCCs before removing silence: (420, 13)
# MFCCs after removing silence: (419, 13)
# MFCCs before removing silence: (430, 13)
# MFCCs after removing silence: (430, 13)
# MFCCs before removing silence: (442, 13)
# MFCCs after removing silence: (438, 13)
# MFCCs before removing silence: (442, 13)
# MFCCs after removing silence: (436, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (453, 13)
# MFCCs before removing silence: (436, 13)
# MFCCs after removing silence: (435, 13)
# MFCCs before removing silence: (431, 13)
# MFCCs after removing silence: (430, 13)
# MFCCs before removing silence: (447, 13)
# MFCCs after removing silence: (447, 13)
# MFCCs before removing silence: (442, 13)
# MFCCs after removing silence: (441, 13)
# MFCCs before removing silence: (470, 13)
# MFCCs after removing silence: (470, 13)
# MFCCs before removing silence: (335, 13)
# MFCCs after removing silence: (334, 13)
# MFCCs before removing silence: (140, 13)
# MFCCs after removing silence: (138, 13)
# MFCCs before removing silence: (425, 13)
# MFCCs after removing silence: (423, 13)
# MFCCs before removing silence: (414, 13)
# MFCCs after removing silence: (411, 13)
# MFCCs before removing silence: (470, 13)
# MFCCs after removing silence: (470, 13)
# MFCCs before removing silence: (470, 13)
# MFCCs after removing silence: (470, 13)
# MFCCs before removing silence: (458, 13)
# MFCCs after removing silence: (458, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (453, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (458, 13)
# MFCCs after removing silence: (458, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (475, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (476, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (485, 13)
# MFCCs before removing silence: (471, 13)
# MFCCs after removing silence: (471, 13)
# MFCCs before removing silence: (458, 13)
# MFCCs after removing silence: (458, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (486, 13)
# MFCCs before removing silence: (573, 13)
# MFCCs after removing silence: (573, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (510, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (505, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (516, 13)
# MFCCs after removing silence: (515, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (485, 13)
# MFCCs before removing silence: (444, 13)
# MFCCs after removing silence: (444, 13)
# MFCCs before removing silence: (452, 13)
# MFCCs after removing silence: (452, 13)
# MFCCs before removing silence: (485, 13)
# MFCCs after removing silence: (485, 13)
# MFCCs before removing silence: (515, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (477, 13)
# MFCCs after removing silence: (477, 13)
# MFCCs before removing silence: (531, 13)
# MFCCs after removing silence: (531, 13)
# MFCCs before removing silence: (477, 13)
# MFCCs after removing silence: (476, 13)
# MFCCs before removing silence: (452, 13)
# MFCCs after removing silence: (452, 13)
# MFCCs before removing silence: (502, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (482, 13)
# MFCCs after removing silence: (482, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (574, 13)
# MFCCs after removing silence: (574, 13)
# MFCCs before removing silence: (448, 13)
# MFCCs after removing silence: (448, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (510, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (506, 13)
# MFCCs before removing silence: (444, 13)
# MFCCs after removing silence: (444, 13)
# MFCCs before removing silence: (523, 13)
# MFCCs after removing silence: (523, 13)
# MFCCs before removing silence: (515, 13)
# MFCCs after removing silence: (515, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (516, 13)
# MFCCs after removing silence: (516, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (520, 13)
# MFCCs after removing silence: (520, 13)
# MFCCs before removing silence: (477, 13)
# MFCCs after removing silence: (477, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (473, 13)
# MFCCs after removing silence: (472, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (515, 13)
# MFCCs after removing silence: (515, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (495, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (506, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (477, 13)
# MFCCs after removing silence: (477, 13)
# MFCCs before removing silence: (527, 13)
# MFCCs after removing silence: (527, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (527, 13)
# MFCCs after removing silence: (527, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (502, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (510, 13)
# MFCCs before removing silence: (485, 13)
# MFCCs after removing silence: (485, 13)
# MFCCs before removing silence: (499, 13)
# MFCCs after removing silence: (499, 13)
# MFCCs before removing silence: (509, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (518, 13)
# MFCCs after removing silence: (518, 13)
# MFCCs before removing silence: (473, 13)
# MFCCs after removing silence: (473, 13)
# MFCCs before removing silence: (515, 13)
# MFCCs after removing silence: (515, 13)
# MFCCs before removing silence: (488, 13)
# MFCCs after removing silence: (488, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (486, 13)
# MFCCs before removing silence: (507, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (501, 13)
# MFCCs after removing silence: (501, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (509, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (486, 13)
# MFCCs after removing silence: (486, 13)
# MFCCs before removing silence: (509, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (495, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (501, 13)
# MFCCs after removing silence: (501, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (495, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (513, 13)
# MFCCs after removing silence: (513, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (513, 13)
# MFCCs after removing silence: (513, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (488, 13)
# MFCCs after removing silence: (488, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (506, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (506, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (507, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (493, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (506, 13)
# MFCCs before removing silence: (490, 13)
# MFCCs after removing silence: (490, 13)
# MFCCs before removing silence: (509, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (481, 13)
# MFCCs after removing silence: (481, 13)
# MFCCs before removing silence: (501, 13)
# MFCCs after removing silence: (501, 13)
# MFCCs before removing silence: (498, 13)
# MFCCs after removing silence: (498, 13)
# MFCCs before removing silence: (507, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (20740, 13)
# MFCCs after removing silence: (20737, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (506, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (496, 13)
# MFCCs before removing silence: (495, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (488, 13)
# MFCCs after removing silence: (488, 13)
# MFCCs before removing silence: (501, 13)
# MFCCs after removing silence: (501, 13)
# MFCCs before removing silence: (509, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (495, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (496, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (622, 13)
# MFCCs after removing silence: (619, 13)
# MFCCs before removing silence: (701, 13)
# MFCCs after removing silence: (701, 13)
# MFCCs before removing silence: (669, 13)
# MFCCs after removing silence: (668, 13)
# MFCCs before removing silence: (553, 13)
# MFCCs after removing silence: (553, 13)
# MFCCs before removing silence: (701, 13)
# MFCCs after removing silence: (700, 13)
# MFCCs before removing silence: (553, 13)
# MFCCs after removing silence: (552, 13)
# MFCCs before removing silence: (615, 13)
# MFCCs after removing silence: (615, 13)
# MFCCs before removing silence: (679, 13)
# MFCCs after removing silence: (679, 13)
# MFCCs before removing silence: (679, 13)
# MFCCs after removing silence: (679, 13)
# MFCCs before removing silence: (467, 13)
# MFCCs after removing silence: (467, 13)
# MFCCs before removing silence: (467, 13)
# MFCCs after removing silence: (467, 13)
# MFCCs before removing silence: (445, 13)
# MFCCs after removing silence: (445, 13)
# MFCCs before removing silence: (611, 13)
# MFCCs after removing silence: (611, 13)
# MFCCs before removing silence: (492, 13)
# MFCCs after removing silence: (492, 13)
# MFCCs before removing silence: (665, 13)
# MFCCs after removing silence: (664, 13)
# MFCCs before removing silence: (467, 13)
# MFCCs after removing silence: (467, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (244, 13)
# MFCCs after removing silence: (244, 13)
# MFCCs before removing silence: (589, 13)
# MFCCs after removing silence: (589, 13)
# MFCCs before removing silence: (539, 13)
# MFCCs after removing silence: (537, 13)
# MFCCs before removing silence: (618, 13)
# MFCCs after removing silence: (618, 13)
# MFCCs before removing silence: (427, 13)
# MFCCs after removing silence: (426, 13)
# MFCCs before removing silence: (600, 13)
# MFCCs after removing silence: (600, 13)
# MFCCs before removing silence: (607, 13)
# MFCCs after removing silence: (606, 13)
# MFCCs before removing silence: (633, 13)
# MFCCs after removing silence: (633, 13)
# MFCCs before removing silence: (359, 13)
# MFCCs after removing silence: (359, 13)
# MFCCs before removing silence: (586, 13)
# MFCCs after removing silence: (586, 13)
# MFCCs before removing silence: (352, 13)
# MFCCs after removing silence: (348, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (550, 13)
# MFCCs before removing silence: (319, 13)
# MFCCs after removing silence: (316, 13)
# MFCCs before removing silence: (636, 13)
# MFCCs after removing silence: (633, 13)
# MFCCs before removing silence: (600, 13)
# MFCCs after removing silence: (599, 13)
# MFCCs before removing silence: (582, 13)
# MFCCs after removing silence: (582, 13)
# MFCCs before removing silence: (665, 13)
# MFCCs after removing silence: (665, 13)
# MFCCs before removing silence: (636, 13)
# MFCCs after removing silence: (636, 13)
# MFCCs before removing silence: (348, 13)
# MFCCs after removing silence: (346, 13)
# MFCCs before removing silence: (571, 13)
# MFCCs after removing silence: (571, 13)
# MFCCs before removing silence: (625, 13)
# MFCCs after removing silence: (625, 13)
# MFCCs before removing silence: (499, 13)
# MFCCs after removing silence: (499, 13)
# MFCCs before removing silence: (636, 13)
# MFCCs after removing silence: (634, 13)
# MFCCs before removing silence: (683, 13)
# MFCCs after removing silence: (681, 13)
# MFCCs before removing silence: (633, 13)
# MFCCs after removing silence: (632, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (345, 13)
# MFCCs after removing silence: (344, 13)
# MFCCs before removing silence: (564, 13)
# MFCCs after removing silence: (564, 13)
# MFCCs before removing silence: (719, 13)
# MFCCs after removing silence: (718, 13)
# MFCCs before removing silence: (381, 13)
# MFCCs after removing silence: (381, 13)
# MFCCs before removing silence: (363, 13)
# MFCCs after removing silence: (362, 13)
# MFCCs before removing silence: (600, 13)
# MFCCs after removing silence: (599, 13)
# MFCCs before removing silence: (564, 13)
# MFCCs after removing silence: (564, 13)
# MFCCs before removing silence: (535, 13)
# MFCCs after removing silence: (535, 13)
# MFCCs before removing silence: (593, 13)
# MFCCs after removing silence: (593, 13)
# MFCCs before removing silence: (769, 13)
# MFCCs after removing silence: (768, 13)
# MFCCs before removing silence: (319, 13)
# MFCCs after removing silence: (319, 13)
# MFCCs before removing silence: (507, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (445, 13)
# MFCCs after removing silence: (442, 13)
# MFCCs before removing silence: (377, 13)
# MFCCs after removing silence: (377, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (560, 13)
# MFCCs before removing silence: (575, 13)
# MFCCs after removing silence: (574, 13)
# MFCCs before removing silence: (683, 13)
# MFCCs after removing silence: (683, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (550, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (510, 13)
# MFCCs before removing silence: (489, 13)
# MFCCs after removing silence: (486, 13)
# MFCCs before removing silence: (488, 13)
# MFCCs after removing silence: (486, 13)
# MFCCs before removing silence: (479, 13)
# MFCCs after removing silence: (479, 13)
# MFCCs before removing silence: (489, 13)
# MFCCs after removing silence: (488, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (550, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (425, 13)
# MFCCs after removing silence: (425, 13)
# MFCCs before removing silence: (519, 13)
# MFCCs after removing silence: (518, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (496, 13)
# MFCCs before removing silence: (551, 13)
# MFCCs after removing silence: (548, 13)
# MFCCs before removing silence: (440, 13)
# MFCCs after removing silence: (440, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (535, 13)
# MFCCs after removing silence: (535, 13)
# MFCCs before removing silence: (464, 13)
# MFCCs after removing silence: (464, 13)
# MFCCs before removing silence: (504, 13)
# MFCCs after removing silence: (504, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (500, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (510, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (511, 13)
# MFCCs after removing silence: (510, 13)
# MFCCs before removing silence: (852, 13)
# MFCCs after removing silence: (847, 13)
# MFCCs before removing silence: (654, 13)
# MFCCs after removing silence: (653, 13)
# MFCCs before removing silence: (471, 13)
# MFCCs after removing silence: (463, 13)
# MFCCs before removing silence: (539, 13)
# MFCCs after removing silence: (537, 13)
# MFCCs before removing silence: (625, 13)
# MFCCs after removing silence: (622, 13)
# MFCCs before removing silence: (737, 13)
# MFCCs after removing silence: (733, 13)
# MFCCs before removing silence: (406, 13)
# MFCCs after removing silence: (404, 13)
# MFCCs before removing silence: (791, 13)
# MFCCs after removing silence: (785, 13)
# MFCCs before removing silence: (705, 13)
# MFCCs after removing silence: (703, 13)
# MFCCs before removing silence: (618, 13)
# MFCCs after removing silence: (615, 13)
# MFCCs before removing silence: (431, 13)
# MFCCs after removing silence: (428, 13)
# MFCCs before removing silence: (643, 13)
# MFCCs after removing silence: (641, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (549, 13)
# MFCCs before removing silence: (622, 13)
# MFCCs after removing silence: (615, 13)
# MFCCs before removing silence: (575, 13)
# MFCCs after removing silence: (568, 13)
# MFCCs before removing silence: (708, 13)
# MFCCs after removing silence: (704, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (459, 13)
# MFCCs before removing silence: (658, 13)
# MFCCs after removing silence: (651, 13)
# MFCCs before removing silence: (676, 13)
# MFCCs after removing silence: (673, 13)
# MFCCs before removing silence: (697, 13)
# MFCCs after removing silence: (692, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (575, 13)
# MFCCs after removing silence: (570, 13)
# MFCCs before removing silence: (690, 13)
# MFCCs after removing silence: (684, 13)
# MFCCs before removing silence: (694, 13)
# MFCCs after removing silence: (689, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (512, 13)
# MFCCs before removing silence: (841, 13)
# MFCCs after removing silence: (835, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (557, 13)
# MFCCs before removing silence: (661, 13)
# MFCCs after removing silence: (661, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (560, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (762, 13)
# MFCCs after removing silence: (762, 13)
# MFCCs before removing silence: (521, 13)
# MFCCs after removing silence: (521, 13)
# MFCCs before removing silence: (597, 13)
# MFCCs after removing silence: (597, 13)
# MFCCs before removing silence: (744, 13)
# MFCCs after removing silence: (744, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (600, 13)
# MFCCs after removing silence: (600, 13)
# MFCCs before removing silence: (834, 13)
# MFCCs after removing silence: (834, 13)
# MFCCs before removing silence: (669, 13)
# MFCCs after removing silence: (667, 13)
# MFCCs before removing silence: (370, 13)
# MFCCs after removing silence: (370, 13)
# MFCCs before removing silence: (532, 13)
# MFCCs after removing silence: (532, 13)
# MFCCs before removing silence: (636, 13)
# MFCCs after removing silence: (636, 13)
# MFCCs before removing silence: (604, 13)
# MFCCs after removing silence: (604, 13)
# MFCCs before removing silence: (647, 13)
# MFCCs after removing silence: (647, 13)
# MFCCs before removing silence: (582, 13)
# MFCCs after removing silence: (582, 13)
# MFCCs before removing silence: (600, 13)
# MFCCs after removing silence: (600, 13)
# MFCCs before removing silence: (629, 13)
# MFCCs after removing silence: (629, 13)
# MFCCs before removing silence: (759, 13)
# MFCCs after removing silence: (757, 13)
# MFCCs before removing silence: (874, 13)
# MFCCs after removing silence: (629, 13)
# MFCCs before removing silence: (701, 13)
# MFCCs after removing silence: (662, 13)
# MFCCs before removing silence: (737, 13)
# MFCCs after removing silence: (696, 13)
# MFCCs before removing silence: (834, 13)
# MFCCs after removing silence: (704, 13)
# MFCCs before removing silence: (849, 13)
# MFCCs after removing silence: (746, 13)
# MFCCs before removing silence: (654, 13)
# MFCCs after removing silence: (654, 13)
# MFCCs before removing silence: (431, 13)
# MFCCs after removing silence: (426, 13)
# MFCCs before removing silence: (593, 13)
# MFCCs after removing silence: (587, 13)
# MFCCs before removing silence: (881, 13)
# MFCCs after removing silence: (877, 13)
# MFCCs before removing silence: (1047, 13)
# MFCCs after removing silence: (1041, 13)
# MFCCs before removing silence: (665, 13)
# MFCCs after removing silence: (647, 13)
# MFCCs before removing silence: (755, 13)
# MFCCs after removing silence: (754, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (557, 13)
# MFCCs before removing silence: (683, 13)
# MFCCs after removing silence: (682, 13)
# MFCCs before removing silence: (975, 13)
# MFCCs after removing silence: (969, 13)
# MFCCs before removing silence: (917, 13)
# MFCCs after removing silence: (906, 13)
# MFCCs before removing silence: (874, 13)
# MFCCs after removing silence: (870, 13)
# MFCCs before removing silence: (863, 13)
# MFCCs after removing silence: (855, 13)
# MFCCs before removing silence: (982, 13)
# MFCCs after removing silence: (975, 13)
# MFCCs before removing silence: (755, 13)
# MFCCs after removing silence: (747, 13)
# MFCCs before removing silence: (755, 13)
# MFCCs after removing silence: (751, 13)
# MFCCs before removing silence: (640, 13)
# MFCCs after removing silence: (636, 13)
# MFCCs before removing silence: (622, 13)
# MFCCs after removing silence: (613, 13)
# MFCCs before removing silence: (856, 13)
# MFCCs after removing silence: (852, 13)
# MFCCs before removing silence: (1025, 13)
# MFCCs after removing silence: (1016, 13)
# MFCCs before removing silence: (802, 13)
# MFCCs after removing silence: (797, 13)
# MFCCs before removing silence: (633, 13)
# MFCCs after removing silence: (626, 13)
# MFCCs before removing silence: (1036, 13)
# MFCCs after removing silence: (1025, 13)
# MFCCs before removing silence: (849, 13)
# MFCCs after removing silence: (840, 13)
# MFCCs before removing silence: (506, 13)
# MFCCs after removing silence: (503, 13)
# MFCCs before removing silence: (566, 13)
# MFCCs after removing silence: (566, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (474, 13)
# MFCCs before removing silence: (420, 13)
# MFCCs after removing silence: (419, 13)
# MFCCs before removing silence: (509, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (510, 13)
# MFCCs before removing silence: (518, 13)
# MFCCs after removing silence: (517, 13)
# MFCCs before removing silence: (475, 13)
# MFCCs after removing silence: (475, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (530, 13)
# MFCCs after removing silence: (529, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (478, 13)
# MFCCs after removing silence: (476, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (515, 13)
# MFCCs after removing silence: (515, 13)
# MFCCs before removing silence: (494, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (513, 13)
# MFCCs before removing silence: (483, 13)
# MFCCs after removing silence: (483, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (518, 13)
# MFCCs after removing silence: (518, 13)
# MFCCs before removing silence: (499, 13)
# MFCCs after removing silence: (499, 13)
# MFCCs before removing silence: (491, 13)
# MFCCs after removing silence: (491, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (464, 13)
# MFCCs after removing silence: (459, 13)
# MFCCs before removing silence: (545, 13)
# MFCCs after removing silence: (545, 13)
# MFCCs before removing silence: (298, 13)
# MFCCs after removing silence: (298, 13)
# MFCCs before removing silence: (539, 13)
# MFCCs after removing silence: (539, 13)
# MFCCs before removing silence: (755, 13)
# MFCCs after removing silence: (755, 13)
# MFCCs before removing silence: (730, 13)
# MFCCs after removing silence: (730, 13)
# MFCCs before removing silence: (773, 13)
# MFCCs after removing silence: (773, 13)
# MFCCs before removing silence: (611, 13)
# MFCCs after removing silence: (611, 13)
# MFCCs before removing silence: (827, 13)
# MFCCs after removing silence: (827, 13)
# MFCCs before removing silence: (251, 13)
# MFCCs after removing silence: (251, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (453, 13)
# MFCCs before removing silence: (604, 13)
# MFCCs after removing silence: (604, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (550, 13)
# MFCCs before removing silence: (615, 13)
# MFCCs after removing silence: (615, 13)
# MFCCs before removing silence: (658, 13)
# MFCCs after removing silence: (658, 13)
# MFCCs before removing silence: (748, 13)
# MFCCs after removing silence: (748, 13)
# MFCCs before removing silence: (759, 13)
# MFCCs after removing silence: (759, 13)
# MFCCs before removing silence: (586, 13)
# MFCCs after removing silence: (586, 13)
# MFCCs before removing silence: (309, 13)
# MFCCs after removing silence: (309, 13)
# MFCCs before removing silence: (568, 13)
# MFCCs after removing silence: (568, 13)
# MFCCs before removing silence: (557, 13)
# MFCCs after removing silence: (555, 13)
# MFCCs before removing silence: (406, 13)
# MFCCs after removing silence: (406, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (291, 13)
# MFCCs after removing silence: (291, 13)
# MFCCs before removing silence: (521, 13)
# MFCCs after removing silence: (521, 13)
# MFCCs before removing silence: (287, 13)
# MFCCs after removing silence: (287, 13)
# MFCCs before removing silence: (568, 13)
# MFCCs after removing silence: (568, 13)
# MFCCs before removing silence: (521, 13)
# MFCCs after removing silence: (520, 13)
# MFCCs before removing silence: (557, 13)
# MFCCs after removing silence: (557, 13)
# MFCCs before removing silence: (413, 13)
# MFCCs after removing silence: (413, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (532, 13)
# MFCCs after removing silence: (532, 13)
# MFCCs before removing silence: (323, 13)
# MFCCs after removing silence: (323, 13)
# MFCCs before removing silence: (381, 13)
# MFCCs after removing silence: (381, 13)
# MFCCs before removing silence: (532, 13)
# MFCCs after removing silence: (532, 13)
# MFCCs before removing silence: (287, 13)
# MFCCs after removing silence: (287, 13)
# MFCCs before removing silence: (427, 13)
# MFCCs after removing silence: (426, 13)
# MFCCs before removing silence: (532, 13)
# MFCCs after removing silence: (532, 13)
# MFCCs before removing silence: (535, 13)
# MFCCs after removing silence: (534, 13)
# MFCCs before removing silence: (755, 13)
# MFCCs after removing silence: (754, 13)
# MFCCs before removing silence: (330, 13)
# MFCCs after removing silence: (330, 13)
# MFCCs before removing silence: (413, 13)
# MFCCs after removing silence: (413, 13)
# MFCCs before removing silence: (568, 13)
# MFCCs after removing silence: (568, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (509, 13)
# MFCCs before removing silence: (640, 13)
# MFCCs after removing silence: (640, 13)
# MFCCs before removing silence: (543, 13)
# MFCCs after removing silence: (543, 13)
# MFCCs before removing silence: (640, 13)
# MFCCs after removing silence: (639, 13)
# MFCCs before removing silence: (658, 13)
# MFCCs after removing silence: (658, 13)
# MFCCs before removing silence: (557, 13)
# MFCCs after removing silence: (557, 13)
# MFCCs before removing silence: (694, 13)
# MFCCs after removing silence: (692, 13)
# MFCCs before removing silence: (744, 13)
# MFCCs after removing silence: (743, 13)
# MFCCs before removing silence: (597, 13)
# MFCCs after removing silence: (594, 13)
# MFCCs before removing silence: (575, 13)
# MFCCs after removing silence: (574, 13)
# MFCCs before removing silence: (607, 13)
# MFCCs after removing silence: (602, 13)
# MFCCs before removing silence: (787, 13)
# MFCCs after removing silence: (786, 13)
# MFCCs before removing silence: (759, 13)
# MFCCs after removing silence: (758, 13)
# MFCCs before removing silence: (388, 13)
# MFCCs after removing silence: (388, 13)
# MFCCs before removing silence: (733, 13)
# MFCCs after removing silence: (730, 13)
# MFCCs before removing silence: (582, 13)
# MFCCs after removing silence: (578, 13)
# MFCCs before removing silence: (471, 13)
# MFCCs after removing silence: (469, 13)
# MFCCs before removing silence: (611, 13)
# MFCCs after removing silence: (608, 13)
# MFCCs before removing silence: (780, 13)
# MFCCs after removing silence: (776, 13)
# MFCCs before removing silence: (564, 13)
# MFCCs after removing silence: (564, 13)
# MFCCs before removing silence: (269, 13)
# MFCCs after removing silence: (269, 13)
# MFCCs before removing silence: (424, 13)
# MFCCs after removing silence: (424, 13)
# MFCCs before removing silence: (399, 13)
# MFCCs after removing silence: (398, 13)
# MFCCs before removing silence: (643, 13)
# MFCCs after removing silence: (642, 13)
# MFCCs before removing silence: (600, 13)
# MFCCs after removing silence: (600, 13)
# MFCCs before removing silence: (625, 13)
# MFCCs after removing silence: (622, 13)
# MFCCs before removing silence: (395, 13)
# MFCCs after removing silence: (393, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (561, 13)
# MFCCs before removing silence: (363, 13)
# MFCCs after removing silence: (362, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (280, 13)
# MFCCs after removing silence: (280, 13)
# MFCCs before removing silence: (298, 13)
# MFCCs after removing silence: (298, 13)
# MFCCs before removing silence: (507, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (442, 13)
# MFCCs after removing silence: (441, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (549, 13)
# MFCCs before removing silence: (442, 13)
# MFCCs after removing silence: (440, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (549, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (262, 13)
# MFCCs after removing silence: (262, 13)
# MFCCs before removing silence: (226, 13)
# MFCCs after removing silence: (226, 13)
# MFCCs before removing silence: (586, 13)
# MFCCs after removing silence: (585, 13)
# MFCCs before removing silence: (478, 13)
# MFCCs after removing silence: (478, 13)
# MFCCs before removing silence: (219, 13)
# MFCCs after removing silence: (219, 13)
# MFCCs before removing silence: (622, 13)
# MFCCs after removing silence: (621, 13)
# MFCCs before removing silence: (298, 13)
# MFCCs after removing silence: (298, 13)
# MFCCs before removing silence: (381, 13)
# MFCCs after removing silence: (381, 13)
# MFCCs before removing silence: (449, 13)
# MFCCs after removing silence: (449, 13)
# MFCCs before removing silence: (593, 13)
# MFCCs after removing silence: (593, 13)
# MFCCs before removing silence: (309, 13)
# MFCCs after removing silence: (309, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (561, 13)
# MFCCs before removing silence: (665, 13)
# MFCCs after removing silence: (664, 13)
# MFCCs before removing silence: (543, 13)
# MFCCs after removing silence: (539, 13)
# MFCCs before removing silence: (766, 13)
# MFCCs after removing silence: (760, 13)
# MFCCs before removing silence: (687, 13)
# MFCCs after removing silence: (684, 13)
# MFCCs before removing silence: (658, 13)
# MFCCs after removing silence: (653, 13)
# MFCCs before removing silence: (474, 13)
# MFCCs after removing silence: (472, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (413, 13)
# MFCCs after removing silence: (412, 13)
# MFCCs before removing silence: (586, 13)
# MFCCs after removing silence: (583, 13)
# MFCCs before removing silence: (427, 13)
# MFCCs after removing silence: (423, 13)
# MFCCs before removing silence: (636, 13)
# MFCCs after removing silence: (635, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (560, 13)
# MFCCs before removing silence: (633, 13)
# MFCCs after removing silence: (633, 13)
# MFCCs before removing silence: (687, 13)
# MFCCs after removing silence: (687, 13)
# MFCCs before removing silence: (377, 13)
# MFCCs after removing silence: (374, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (557, 13)
# MFCCs before removing silence: (431, 13)
# MFCCs after removing silence: (431, 13)
# MFCCs before removing silence: (427, 13)
# MFCCs after removing silence: (427, 13)
# MFCCs before removing silence: (535, 13)
# MFCCs after removing silence: (532, 13)
# MFCCs before removing silence: (478, 13)
# MFCCs after removing silence: (477, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (548, 13)
# MFCCs before removing silence: (489, 13)
# MFCCs after removing silence: (488, 13)
# MFCCs before removing silence: (269, 13)
# MFCCs after removing silence: (269, 13)
# MFCCs before removing silence: (395, 13)
# MFCCs after removing silence: (394, 13)
# MFCCs before removing silence: (762, 13)
# MFCCs after removing silence: (758, 13)
# MFCCs before removing silence: (625, 13)
# MFCCs after removing silence: (620, 13)
# MFCCs before removing silence: (467, 13)
# MFCCs after removing silence: (464, 13)
# MFCCs before removing silence: (622, 13)
# MFCCs after removing silence: (620, 13)
# MFCCs before removing silence: (485, 13)
# MFCCs after removing silence: (479, 13)
# MFCCs before removing silence: (521, 13)
# MFCCs after removing silence: (519, 13)
# MFCCs before removing silence: (471, 13)
# MFCCs after removing silence: (469, 13)
# MFCCs before removing silence: (723, 13)
# MFCCs after removing silence: (722, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (514, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (550, 13)
# MFCCs before removing silence: (669, 13)
# MFCCs after removing silence: (667, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (494, 13)
# MFCCs before removing silence: (604, 13)
# MFCCs after removing silence: (602, 13)
# MFCCs before removing silence: (359, 13)
# MFCCs after removing silence: (357, 13)
# MFCCs before removing silence: (370, 13)
# MFCCs after removing silence: (370, 13)
# MFCCs before removing silence: (557, 13)
# MFCCs after removing silence: (556, 13)
# MFCCs before removing silence: (676, 13)
# MFCCs after removing silence: (676, 13)
# MFCCs before removing silence: (640, 13)
# MFCCs after removing silence: (640, 13)
# MFCCs before removing silence: (561, 13)
# MFCCs after removing silence: (560, 13)
# MFCCs before removing silence: (658, 13)
# MFCCs after removing silence: (657, 13)
# MFCCs before removing silence: (748, 13)
# MFCCs after removing silence: (747, 13)
# MFCCs before removing silence: (478, 13)
# MFCCs after removing silence: (477, 13)
# MFCCs before removing silence: (334, 13)
# MFCCs after removing silence: (333, 13)
# MFCCs before removing silence: (363, 13)
# MFCCs after removing silence: (363, 13)
# MFCCs before removing silence: (413, 13)
# MFCCs after removing silence: (413, 13)
# MFCCs before removing silence: (316, 13)
# MFCCs after removing silence: (315, 13)
# MFCCs before removing silence: (395, 13)
# MFCCs after removing silence: (392, 13)
# MFCCs before removing silence: (777, 13)
# MFCCs after removing silence: (777, 13)
# MFCCs before removing silence: (593, 13)
# MFCCs after removing silence: (593, 13)
# MFCCs before removing silence: (478, 13)
# MFCCs after removing silence: (475, 13)
# MFCCs before removing silence: (273, 13)
# MFCCs after removing silence: (273, 13)
# MFCCs before removing silence: (309, 13)
# MFCCs after removing silence: (305, 13)
# MFCCs before removing silence: (291, 13)
# MFCCs after removing silence: (289, 13)
# MFCCs before removing silence: (766, 13)
# MFCCs after removing silence: (766, 13)
# MFCCs before removing silence: (532, 13)
# MFCCs after removing silence: (531, 13)
# MFCCs before removing silence: (539, 13)
# MFCCs after removing silence: (537, 13)
# MFCCs before removing silence: (424, 13)
# MFCCs after removing silence: (421, 13)
# MFCCs before removing silence: (640, 13)
# MFCCs after removing silence: (637, 13)
# MFCCs before removing silence: (417, 13)
# MFCCs after removing silence: (416, 13)
# MFCCs before removing silence: (568, 13)
# MFCCs after removing silence: (566, 13)
# MFCCs before removing silence: (467, 13)
# MFCCs after removing silence: (467, 13)
# MFCCs before removing silence: (417, 13)
# MFCCs after removing silence: (417, 13)
# MFCCs before removing silence: (485, 13)
# MFCCs after removing silence: (485, 13)
# MFCCs before removing silence: (381, 13)
# MFCCs after removing silence: (381, 13)
# MFCCs before removing silence: (460, 13)
# MFCCs after removing silence: (460, 13)
# MFCCs before removing silence: (431, 13)
# MFCCs after removing silence: (431, 13)
# MFCCs before removing silence: (399, 13)
# MFCCs after removing silence: (397, 13)
# MFCCs before removing silence: (388, 13)
# MFCCs after removing silence: (388, 13)
# MFCCs before removing silence: (622, 13)
# MFCCs after removing silence: (622, 13)
# MFCCs before removing silence: (478, 13)
# MFCCs after removing silence: (478, 13)
# MFCCs before removing silence: (370, 13)
# MFCCs after removing silence: (370, 13)
# MFCCs before removing silence: (597, 13)
# MFCCs after removing silence: (597, 13)
# MFCCs before removing silence: (489, 13)
# MFCCs after removing silence: (489, 13)
# MFCCs before removing silence: (611, 13)
# MFCCs after removing silence: (611, 13)
# MFCCs before removing silence: (593, 13)
# MFCCs after removing silence: (593, 13)
# MFCCs before removing silence: (543, 13)
# MFCCs after removing silence: (543, 13)
# MFCCs before removing silence: (715, 13)
# MFCCs after removing silence: (715, 13)
# MFCCs before removing silence: (485, 13)
# MFCCs after removing silence: (403, 13)
# MFCCs before removing silence: (535, 13)
# MFCCs after removing silence: (445, 13)
# MFCCs before removing silence: (618, 13)
# MFCCs after removing silence: (547, 13)
# MFCCs before removing silence: (291, 13)
# MFCCs after removing silence: (217, 13)
# MFCCs before removing silence: (532, 13)
# MFCCs after removing silence: (495, 13)
# MFCCs before removing silence: (571, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (514, 13)
# MFCCs after removing silence: (414, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (420, 13)
# MFCCs before removing silence: (582, 13)
# MFCCs after removing silence: (499, 13)
# MFCCs before removing silence: (413, 13)
# MFCCs after removing silence: (315, 13)
# MFCCs before removing silence: (463, 13)
# MFCCs after removing silence: (462, 13)
# MFCCs before removing silence: (679, 13)
# MFCCs after removing silence: (608, 13)
# MFCCs before removing silence: (471, 13)
# MFCCs after removing silence: (419, 13)
# MFCCs before removing silence: (384, 13)
# MFCCs after removing silence: (276, 13)
# MFCCs before removing silence: (917, 13)
# MFCCs after removing silence: (917, 13)
# MFCCs before removing silence: (546, 13)
# MFCCs after removing silence: (545, 13)
# MFCCs before removing silence: (597, 13)
# MFCCs after removing silence: (597, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (453, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (604, 13)
# MFCCs after removing silence: (603, 13)
# MFCCs before removing silence: (607, 13)
# MFCCs after removing silence: (607, 13)
# MFCCs before removing silence: (733, 13)
# MFCCs after removing silence: (574, 13)
# MFCCs before removing silence: (593, 13)
# MFCCs after removing silence: (593, 13)
# MFCCs before removing silence: (651, 13)
# MFCCs after removing silence: (575, 13)
# MFCCs before removing silence: (654, 13)
# MFCCs after removing silence: (578, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (444, 13)
# MFCCs before removing silence: (557, 13)
# MFCCs after removing silence: (449, 13)
# MFCCs before removing silence: (503, 13)
# MFCCs after removing silence: (414, 13)
# MFCCs before removing silence: (582, 13)
# MFCCs after removing silence: (524, 13)
# MFCCs before removing silence: (507, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (510, 13)
# MFCCs after removing silence: (507, 13)
# MFCCs before removing silence: (895, 13)
# MFCCs after removing silence: (892, 13)
# MFCCs before removing silence: (665, 13)
# MFCCs after removing silence: (662, 13)
# MFCCs before removing silence: (568, 13)
# MFCCs after removing silence: (565, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (548, 13)
# MFCCs before removing silence: (517, 13)
# MFCCs after removing silence: (511, 13)
# MFCCs before removing silence: (600, 13)
# MFCCs after removing silence: (599, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (446, 13)
# MFCCs before removing silence: (611, 13)
# MFCCs after removing silence: (601, 13)
# MFCCs before removing silence: (651, 13)
# MFCCs after removing silence: (644, 13)
# MFCCs before removing silence: (381, 13)
# MFCCs after removing silence: (379, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (579, 13)
# MFCCs before removing silence: (676, 13)
# MFCCs after removing silence: (670, 13)
# MFCCs before removing silence: (453, 13)
# MFCCs after removing silence: (449, 13)
# MFCCs before removing silence: (579, 13)
# MFCCs after removing silence: (576, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (496, 13)
# MFCCs after removing silence: (493, 13)
# MFCCs before removing silence: (348, 13)
# MFCCs after removing silence: (344, 13)
# MFCCs before removing silence: (550, 13)
# MFCCs after removing silence: (541, 13)
# MFCCs before removing silence: (726, 13)
# MFCCs after removing silence: (722, 13)
# MFCCs before removing silence: (669, 13)
# MFCCs after removing silence: (667, 13)
# MFCCs before removing silence: (543, 13)
# MFCCs after removing silence: (540, 13)
# MFCCs before removing silence: (438, 13)
# MFCCs after removing silence: (435, 13)
# MFCCs before removing silence: (665, 13)
# MFCCs after removing silence: (660, 13)
# MFCCs before removing silence: (402, 13)
# MFCCs after removing silence: (401, 13)
# MFCCs before removing silence: (363, 13)
# MFCCs after removing silence: (356, 13)
# MFCCs before removing silence: (586, 13)
# MFCCs after removing silence: (583, 13)
# MFCCs before removing silence: (438, 13)
# MFCCs after removing silence: (434, 13)
# MFCCs before removing silence: (370, 13)
# MFCCs after removing silence: (361, 13)

# %% [markdown]
# ## -----> We can see here that the size of the mfcc features has decreased after removing the frames ot silence

# %% [markdown]
# # Splitting into test and train sets according to gender

# %%
train_mfccs, test_mfccs = train_test_split(r'mfcc_spanish')
# Out:
# Train male MFCCs shape: (239,)
# Test male MFCCs shape: (120,)
# Train female MFCCs shape: (243,)
# Test female MFCCs shape: (122,)
# Train MFCCs shape: (482,)
# Test MFCCs shape: (242,)
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\3397580047.py:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print(f"Train MFCCs shape: {np.array(train_mfccs).shape}")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\3397580047.py:46: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print(f"Test MFCCs shape: {np.array(test_mfccs).shape}")

# %% [markdown]
# # Stacking vertically the train and test MFCC features so that we can fit the gmm models

# %%
#stack vertically the train MFCC features 
mfcc_train = []
for train_mfcc in train_mfccs:
    mfcc_train.append(train_mfcc)
mfcc_train = np.concatenate(mfcc_train, axis=0)

#stack vertically the test MFCC features 
mfcc_test = []
for test_mfcc in test_mfccs:
    mfcc_test.append(test_mfcc)
mfcc_test = np.concatenate(mfcc_test, axis=0)

# %% [markdown]
# # Saving the test set into a txt file

# %%
#Save the test mfccs in a file
test_mfccs = np.vstack(test_mfccs)
test_mfccs = np.array(test_mfccs, dtype=float)
np.savetxt(r'spanishTest', test_mfccs, delimiter=',')

# %%
mfcc_train.shape
# Out:
# (273016, 13)

# %% [markdown]
# # Training the different Gmm Models

# %%
gmm16 = gmm16(mfcc_train)

# %%
gmm32 = gmm32(mfcc_train)

# %%
gmm64 = gmm64(mfcc_train)

# %%
gmm128= gmm128(mfcc_train)

# %%
gmm256= gmm256(mfcc_train)

# %% [markdown]
# # Evaluate the performance of each GMM model on the test set using the score_samples() function that returns an array containing the log-likelihood of each frame of the mfcc features

# %%
scores = []
for model in [gmm16, gmm32, gmm64, gmm128, gmm256]:
    score = model.score_samples(mfcc_test)
    scores.append(score)

# Print the scores
print('GMM16 score:', scores[0])
print('GMM32 score:', scores[1])
print('GMM64 score:', scores[2])
print('GMM128 score:', scores[3])
print('GMM256 score:', scores[4])
# Out:
# GMM16 score: [-49.05870833 -53.82938823 -54.62287386 ... -55.33671129 -54.93640764
#  -56.76824437]
# GMM32 score: [-49.83049892 -55.05438122 -54.63209593 ... -50.62301822 -51.85412279
#  -54.43271046]
# GMM64 score: [-49.73172227 -54.93804853 -54.90668681 ... -50.52303528 -51.50889269
#  -54.14906249]
# GMM128 score: [-51.05292796 -54.20700153 -54.10273388 ... -48.42882178 -49.66743458
#  -51.65727999]
# GMM256 score: [-51.45463984 -52.62560254 -52.26864691 ... -48.51905157 -48.50956296
#  -51.43966293]

# %% [markdown]
# # Comparing the size of our mfcc_test set with the size of the scores array

# %%
mfcc_test.shape
# Out:
# (126588, 13)

# %% [markdown]
# # Indeed the size of the scores array is the same

# %%
 scores[0].shape
# Out:
# (126588,)

# %% [markdown]
# # In order to compare between the different GMM Models we need to calculate the score for the hole test set and we can do that by calculating the mean of the individual scores

# %%
#calculationg the score of the hole test set
print('GMM16 score:', scores[0].mean())
print('GMM32 score:', scores[1].mean())
print('GMM64 score:', scores[2].mean())
print('GMM128 score:', scores[3].mean())
print('GMM256 score:', scores[4].mean())
# Out:
# GMM16 score: -50.398661978238515
# GMM32 score: -49.97678880120494
# GMM64 score: -49.52923493099654
# GMM128 score: -49.15012612764365
# GMM256 score: -48.810046543206504

# %% [markdown]
# ### From the results above we can see that the best score (the closest one to 0) is given by the model using 16 gaussians
